# %%
import pandas as pd
import numpy as np

# %%
path = "C:/Users/PC/Desktop/AP Data Science/attrition_data (1).csv"
df = pd.read_csv(path)
df
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      49  Travel_Frequently        279  Research & Development
# 1      33  Travel_Frequently       1392  Research & Development
# 2      27      Travel_Rarely        591  Research & Development
# 3      32  Travel_Frequently       1005  Research & Development
# 4      59      Travel_Rarely       1324  Research & Development
# ...   ...                ...        ...                     ...
# 1465   48         Non-Travel       1262  Research & Development
# 1466   31  Travel_Frequently        793                   Sales
# 1467   34  Travel_Frequently       1003  Research & Development
# 1468   29  Travel_Frequently        490  Research & Development
# 1469   29      Travel_Rarely       1401  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    8          1  Life Sciences              1
# 1                    3          4  Life Sciences              1
# ...

# %%
df = df.sample(frac=1)

# %%
df.tail()
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 1192   29      Travel_Rarely        468  Research & Development
# 33     46  Travel_Frequently       1211                   Sales
# 499    33      Travel_Rarely        586                   Sales
# 506    32      Travel_Rarely        638  Research & Development
# 1240   31  Travel_Frequently        307  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1192                28          4        Medical              1
# 33                   5          4      Marketing              1
# 499                  1          3        Medical              1
# 506                  8          2        Medical              1
# 1240                29          2        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction  ... StandardHours  \
# 1192            2054                        4  ...            80
# ...

# %%
df = df.reset_index()
df.tail()
# Out:
#       index  Age     BusinessTravel  DailyRate              Department  \
# 1465   1192   29      Travel_Rarely        468  Research & Development
# 1466     33   46  Travel_Frequently       1211                   Sales
# 1467    499   33      Travel_Rarely        586                   Sales
# 1468    506   32      Travel_Rarely        638  Research & Development
# 1469   1240   31  Travel_Frequently        307  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                28          4        Medical              1
# 1466                 5          4      Marketing              1
# 1467                 1          3        Medical              1
# 1468                 8          2        Medical              1
# 1469                29          2        Medical              1
#
#       EmployeeNumber  ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# ...

# %%
df.dtypes
# Out:
# index                         int64
# Age                           int64
# BusinessTravel               object
# DailyRate                     int64
# Department                   object
# DistanceFromHome              int64
# Education                     int64
# EducationField               object
# EmployeeCount                 int64
# EmployeeNumber                int64
# EnvironmentSatisfaction       int64
# Gender                       object
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                      int64
# JobRole                      object
# JobSatisfaction               int64
# MaritalStatus                object
# MonthlyIncome               float64
# MonthlyRate                   int64
# NumCompaniesWorked            int64
# Over18                       object
# OverTime                     object
# PercentSalaryHike             int64
# PerformanceRating             int64
# RelationshipSatisfaction      int64
# ...

# %%
df.isnull().sum()
# Out:
# index                        0
# Age                          0
# BusinessTravel               0
# DailyRate                    0
# Department                   0
# DistanceFromHome             0
# Education                    0
# EducationField               0
# EmployeeCount                0
# EmployeeNumber               0
# EnvironmentSatisfaction      0
# Gender                       0
# HourlyRate                   0
# JobInvolvement               0
# JobLevel                     0
# JobRole                      0
# JobSatisfaction              0
# MaritalStatus                0
# MonthlyIncome               48
# MonthlyRate                  0
# NumCompaniesWorked           0
# Over18                       0
# OverTime                    25
# PercentSalaryHike            0
# PerformanceRating            0
# RelationshipSatisfaction     0
# StandardHours                0
# StockOptionLevel             0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# ...

# %%
df.dropna(subset=["Attrition"], axis=0, inplace=True)
df["Attrition"].isnull().sum()
# Out:
# 0

# %%
mean_monthly_income = df["MonthlyIncome"].mean(axis=0)
print(mean_monthly_income)
df["MonthlyIncome"].replace(np.nan, mean_monthly_income, inplace=True)
# Out:
# 6521.582251082251

# %%
df.dropna(subset=["OverTime"], axis=0, inplace=True)
df["OverTime"].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# index                       0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe()
# Out:
#              index          Age    DailyRate  DistanceFromHome    Education  \
# count  1409.000000  1409.000000  1409.000000       1409.000000  1409.000000
# mean    722.988644    36.966643   800.676366          9.213627     2.911994
# std     411.242014     9.187265   404.576138          8.085336     1.021463
# min       0.000000    18.000000   102.000000          1.000000     1.000000
# 25%     370.000000    30.000000   464.000000          2.000000     2.000000
# 50%     725.000000    36.000000   798.000000          7.000000     3.000000
# 75%    1077.000000    43.000000  1157.000000         14.000000     4.000000
# max    1433.000000    60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1409.0     1409.000000              1409.000000  1409.000000
# mean             1.0     1048.221434                 2.722498    65.766501
# ...

# %%
df.to_csv("attrition_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-bbd96a8e652e> in <module>
# ----> 1 df.to_csv("attrition_data.csv", index=False)
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
